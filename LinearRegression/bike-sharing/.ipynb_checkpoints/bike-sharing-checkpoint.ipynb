# %% [markdown]
# # BIke Sharing data analytics
#
# ### Bike Sharing in Washington D.C.
# #### https://www.kaggle.com/marklvl/bike-sharing-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('day.csv')

# %%
df.head(20)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1        0        6           0
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
# instant       731 non-null int64
# dteday        731 non-null object
# season        731 non-null int64
# yr            731 non-null int64
# mnth          731 non-null int64
# holiday       731 non-null int64
# weekday       731 non-null int64
# workingday    731 non-null int64
# weathersit    731 non-null int64
# temp          731 non-null float64
# atemp         731 non-null float64
# hum           731 non-null float64
# windspeed     731 non-null float64
# casual        731 non-null int64
# registered    731 non-null int64
# cnt           731 non-null int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# ### Verifica se existem dados nulos no dataset

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
lYText = ['Primavera',u'Verão','Outono', 'Inverno']
lXText = ['Domingo', 'Segunda', u'Terça', 'Quarta', 'Quinta', 'Sexta', u'Sábado']
f, ax  = plt.subplots(figsize=(9, 6))
data   = df.pivot_table("registered", "weekday", "season")
ax     = sns.heatmap(data, linewidths=.5, ax=ax , cmap='Blues')

ax.set_xlabel(u'Estações do ano')
ax.set_ylabel('Dias da semana')
ax.set_yticklabels(lXText, fontsize=10, rotation=30)
ax.set_xticklabels(lYText, fontsize=10, rotation=30)
# Out:
# [Text(0.5,0,u'Primavera'),
#  Text(1.5,0,u'Ver\xe3o'),
#  Text(2.5,0,u'Outono'),
#  Text(3.5,0,u'Inverno')]

# %%
df['weathersit'].hist(bins=30, color='darkred', alpha=0.8)
